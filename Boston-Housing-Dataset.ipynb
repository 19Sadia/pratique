# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# MEDV - Median value of owner-occupied homes in $1000's

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
d=pd.read_csv('housing-unclean.csv', names=column_names)
d
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 601  0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873  4.0  305.0
# 602  0.18836   0.0   6.91   0.0  0.448  5.786  33.3  5.1004  3.0  233.0
# 603  0.33147   0.0   6.20   0.0  0.507  8.247  70.4  3.6519  8.0  307.0
# 604  0.05372   0.0  13.92   0.0  0.437  6.549  51.0  5.9604  4.0  289.0
# 605  0.04462  25.0   4.86   0.0  0.426  6.619  70.4  5.4007  4.0  281.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     554 non-null    float64
#  1   ZN       560 non-null    float64
#  2   INDUS    606 non-null    float64
#  3   CHAS     555 non-null    float64
#  4   NOX      606 non-null    float64
#  5   RM       606 non-null    float64
#  6   AGE      587 non-null    float64
#  7   DIS      606 non-null    float64
#  8   RAD      571 non-null    float64
#  9   TAX      589 non-null    float64
#  10  PTRATIO  606 non-null    float64
#  11  B        606 non-null    float64
#  12  LSTAT    606 non-null    float64
#  13  MEDV     606 non-null    float64
# dtypes: float64(14)
# memory usage: 66.4 KB

# %%
d.describe()
# Out:
#              CRIM          ZN      INDUS        CHAS         NOX          RM  \
# count  554.000000  560.000000  606.00000  555.000000  606.000000  606.000000
# mean     3.479817   11.763393   11.15538    0.070270    0.554173    6.289551
# std      8.324516   23.839314    6.84360    0.255833    0.115411    0.736461
# min      0.006320    0.000000    0.46000    0.000000    0.385000    3.561000
# 25%      0.079870    0.000000    5.19000    0.000000    0.449000    5.879250
# 50%      0.253715    0.000000    9.69000    0.000000    0.538000    6.208500
# 75%      3.519828   13.750000   18.10000    0.000000    0.624000    6.629750
# max     88.976200  100.000000   27.74000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  587.000000  606.000000  571.000000  589.000000  606.000000  606.000000
# mean    68.535094    3.773636    9.378284  407.353141   18.453135  358.054142
# ...

# %%
#outliers- indus,age,dis,rad,tax,b,

# %% [markdown]
# ### EDA

# %%
sns.histplot(x='INDUS', kde=True, data=d)
# Out:
# <Axes: xlabel='INDUS', ylabel='Count'>

# %%
fig,ax=plt.subplots(12,2,figsize=(20,60))
m,n=0,0
for col in d:
    sns.histplot(d[col], kde=True, ax=ax[m][n])
    sns.distplot(d[col], hist=False, ax=ax[m][n+1])
    m+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 m,n=0,0
#       3 for col in d:
# ----> 4     sns.histplot(d[col], kde=True, ax=ax[m][n])
#       5     sns.distplot(d[col], hist=False, ax=ax[m][n+1])
#       6     m+=1
#
# IndexError: index 12 is out of bounds for axis 0 with size 12

# %%
#oulier=crim,zn,b,dis,ptratio,age

# %%
plt.figure(figsize=(20,60))
plot=1
for col in d:
    if plot<=15:
        ax=plt.subplot(12,2,plot)
        sns.histplot(d[col],kde=True)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('count',fontsize=20)
    plot+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,60))
plot=1
for col in d:
    if plot<=15:
        ax=plt.subplot(12,2,plot)
        sns.scatterplot(d[col])
        plt.xlabel(col,fontsize=20)
        plt.ylabel('count',fontsize=20)
    plot+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,60))
plot=1
for col in d:
    if plot<=15:
        ax=plt.subplot(12,2,plot)
        sns.boxplot(d[col])
        plt.xlabel(col,fontsize=20)
        plt.ylabel('count',fontsize=20)
    plot+=1
plt.tight_layout()

# %% [markdown]
# ### CRIM

# %%
Q1=d['CRIM'].quantile(0.25)
Q3=d['CRIM'].quantile(0.75)
print(Q1)
print(Q3)
iqr=Q3-Q1
print(iqr)

# %%
upper=Q3+1.5*iqr
lower=Q1+1.5*iqr
print(upper)
print(lower)

perc = np.shape(d['CRIM'])[0] * 100.0 / np.shape(d)[0]
perc

# %%
d.loc[d['CRIM']>upper]

# %%
d.loc[d['CRIM']<lower]

# %% [markdown]
# #### ZN

# %%
Q1=d['ZN'].quantile(0.25)
Q3=d['ZN'].quantile(0.75)
print(Q1)
print(Q3)
iqr=Q3-Q1
print(iqr)

# %%
upper=Q3+1.5*iqr
lower=Q1+1.5*iqr
print(upper)
print(lower)

perc = np.shape(d['ZN'])[0] * 100.0 / np.shape(d)[0]
perc

# %%
d.loc[d['ZN']>upper]

# %%
d.loc[d['ZN']<lower]

# %% [markdown]
# #### RM

# %%
Q1=d['RM'].quantile(0.25)
Q3=d['RM'].quantile(0.75)
print(Q1)
print(Q3)
iqr=Q3-Q1
print(iqr)
# Out:
# 5.87925
# 6.62975
# 0.7504999999999997

# %%
upper=Q3+1.5*iqr
lower=Q1+1.5*iqr
print(upper)
print(lower)
# Out:
# 7.7555
# 7.004999999999999

# %%
d.loc[d['RM']>upper]
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 97   0.12083   0.0   2.89   0.0  0.4450  8.069  76.0  3.4952   2.0  276.0
# 98   0.08187   0.0   2.89   0.0  0.4450  7.820  36.9  3.4952   2.0  276.0
# 162  1.83377   0.0  19.58   1.0  0.6050  7.802  98.2  2.0407   5.0  403.0
# 163  1.51902   0.0  19.58   1.0  0.6050  8.375  93.9  2.1620   5.0  403.0
# 166  2.01019   0.0  19.58   0.0  0.6050  7.929  96.2  2.0459   5.0  403.0
# 180  0.06588   0.0   2.46   0.0  0.4880  7.765  83.3  2.7410   3.0  193.0
# 186  0.05602   0.0   2.46   0.0  0.4880  7.831  53.6  3.1992   3.0  193.0
# 195  0.01381  80.0   0.46   0.0  0.4220  7.875  32.0  5.6484   4.0  255.0
# 203  0.03510  95.0   2.68   0.0  0.4161  7.853  33.2  5.1180   4.0  224.0
# 204  0.02009  95.0   2.68   0.0  0.4161  8.034  31.9  5.1180   4.0  224.0
# 224  0.31533   0.0   6.20   0.0  0.5040  8.266  78.3  2.8944   8.0  307.0
# 225  0.52693   0.0   6.20   0.0  0.5040  8.725  83.0  2.8944   8.0  307.0
# ...

# %%
d.loc[d['RM']>lower]
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 2    0.02729   0.0   7.07   0.0  0.4690  7.185  61.1  4.9671   2.0  242.0
# 4    0.06905   0.0   2.18   0.0  0.4580  7.147  54.2  6.0622   3.0  222.0
# 40   0.03359  75.0   2.95   0.0  0.4280  7.024  15.8  5.4011   3.0  252.0
# 55   0.01311  90.0   1.22   0.0  0.4030  7.249  21.9  8.6966   5.0  226.0
# 64   0.01951  17.5   1.38   0.0  0.4161  7.104  59.5  9.2229   3.0  216.0
# ..       ...   ...    ...   ...     ...    ...   ...     ...   ...    ...
# 581  0.00906  90.0   2.97   0.0  0.4000  7.088  20.8  7.3073   1.0  285.0
# 588  0.06860   0.0   2.89   0.0  0.4450  7.416  62.5  3.4952   2.0  276.0
# 599  6.53876   0.0  18.10   1.0  0.6310  7.016  97.5  1.2024  24.0  666.0
# 600  0.04011  80.0   1.52   0.0  0.4040  7.287  34.1  7.3090   2.0  329.0
# 603  0.33147   0.0   6.20   0.0  0.5070  8.247  70.4  3.6519   8.0  307.0
#
#      PTRATIO       B  LSTAT  MEDV
# 2       17.8  392.83   4.03  34.7
# ...

# %% [markdown]
# #### B

# %%
Q1=d['B'].quantile(0.25)
Q3=d['B'].quantile(0.75)
print(Q1)
print(Q3)
iqr=Q3-Q1
print(iqr)
# Out:
# 374.835
# 396.295
# 21.460000000000036

# %%
upper=Q3+1.5*iqr
lower=Q1+1.5*iqr
print(upper)
print(lower)
# Out:
# 428.48500000000007
# 407.02500000000003

# %%
d.loc[d['B']>upper]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
d.loc[d['B']<lower]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 601  0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873  4.0  305.0
# 602  0.18836   0.0   6.91   0.0  0.448  5.786  33.3  5.1004  3.0  233.0
# 603  0.33147   0.0   6.20   0.0  0.507  8.247  70.4  3.6519  8.0  307.0
# 604  0.05372   0.0  13.92   0.0  0.437  6.549  51.0  5.9604  4.0  289.0
# 605  0.04462  25.0   4.86   0.0  0.426  6.619  70.4  5.4007  4.0  281.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# #### LSTAT

# %%
Q1=d['LSTAT'].quantile(0.25)
Q3=d['LSTAT'].quantile(0.75)
print(Q1)
print(Q3)
iqr=Q3-Q1
print(iqr)
# Out:
# 6.905
# 16.955000000000002
# 10.05

# %%
upper=Q3+1.5*iqr
lower=Q1+1.5*iqr
print(upper)
print(lower)
# Out:
# 32.03
# 21.98

# %%
da=d.loc[d['LSTAT']<upper]

# %%
d.loc[d['LSTAT']<lower]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 601  0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873  4.0  305.0
# 602  0.18836   0.0   6.91   0.0  0.448  5.786  33.3  5.1004  3.0  233.0
# 603  0.33147   0.0   6.20   0.0  0.507  8.247  70.4  3.6519  8.0  307.0
# 604  0.05372   0.0  13.92   0.0  0.437  6.549  51.0  5.9604  4.0  289.0
# 605  0.04462  25.0   4.86   0.0  0.426  6.619  70.4  5.4007  4.0  281.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# #### MEDV

# %%
Q1=da['MEDV'].quantile(0.25)
Q3=da['MEDV'].quantile(0.75)
print(Q1)
print(Q3)
iqr=Q3-Q1
print(iqr)
# Out:
# 17.1
# 26.4
# 9.299999999999997

# %%
upper=Q3+1.5*iqr
lower=Q1+1.5*iqr
print(upper)
print(lower)
# Out:
# 40.349999999999994
# 31.049999999999997

# %%
da.loc[da['MEDV']>upper]
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS   RAD    TAX  \
# 98   0.08187   0.0   2.89   0.0  0.4450  7.820   36.9  3.4952   2.0  276.0
# 157  1.22358   0.0  19.58   0.0  0.6050  6.943   97.4  1.8773   5.0  403.0
# 161  1.46336   0.0  19.58   0.0  0.6050  7.489   90.8  1.9709   5.0  403.0
# 162  1.83377   0.0  19.58   1.0  0.6050  7.802   98.2  2.0407   5.0  403.0
# 163  1.51902   0.0  19.58   1.0  0.6050  8.375   93.9  2.1620   5.0  403.0
# 166  2.01019   0.0  19.58   0.0  0.6050  7.929   96.2  2.0459   5.0  403.0
# 186  0.05602   0.0   2.46   0.0  0.4880  7.831   53.6  3.1992   3.0  193.0
# 195  0.01381  80.0   0.46   0.0  0.4220  7.875   32.0  5.6484   4.0  255.0
# 202  0.02177  82.5   2.03   0.0  0.4150  7.610   15.7  6.2700   2.0  348.0
# 203  0.03510  95.0   2.68   0.0  0.4161  7.853   33.2  5.1180   4.0  224.0
# 204  0.02009  95.0   2.68   0.0  0.4161  8.034   31.9  5.1180   4.0  224.0
# ...

# %%
da.loc[da['MEDV']<lower]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# 6    0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605  5.0  311.0
# 7    0.14455  12.5   7.87   0.0  0.524  6.172  96.1  5.9505  5.0  311.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 598  0.04417  70.0   2.24   0.0  0.400  6.871  47.4  7.8278  5.0  358.0
# 601  0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873  4.0  305.0
# 602  0.18836   0.0   6.91   0.0  0.448  5.786  33.3  5.1004  3.0  233.0
# 604  0.05372   0.0  13.92   0.0  0.437  6.549  51.0  5.9604  4.0  289.0
# 605  0.04462  25.0   4.86   0.0  0.426  6.619  70.4  5.4007  4.0  281.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
dat=da.loc[da['MEDV']<upper]

# %%
dat.shape
# Out:
# (557, 14)

# %%
dat.isna().sum()
# Out:
# CRIM       46
# ZN         40
# INDUS       0
# CHAS       45
# NOX         0
# RM          0
# AGE        15
# DIS         0
# RAD        30
# TAX        14
# PTRATIO     0
# B           0
# LSTAT       0
# MEDV        0
# dtype: int64

# %%
dat['CRIM'].hist()
plt.show()

# %%
dat['CRIM'].fillna(value=dat['CRIM'].median(),inplace=True)

# %%
dat['ZN'].hist()
plt.show()

# %%
dat['ZN'].fillna(value=dat['ZN'].median(),inplace=True)

# %%
dat['CHAS'].hist()
plt.show()

# %%
dat['CHAS'].fillna(value=dat['CHAS'].median(),inplace=True)

# %%
dat['AGE'].hist()
plt.show()

# %%
dat['AGE'].fillna(value=dat['AGE'].mean(),inplace=True)

# %%
dat['RAD'].hist()
plt.show()

# %%
dat['RAD'].fillna(value=dat['RAD'].mean(),inplace=True)

# %%
dat['TAX'].hist()
plt.show()

# %%
dat['TAX'].fillna(value=dat['TAX'].mean(),inplace=True)

# %%
dat.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
dat.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.180980  0.377368 -0.050280  0.392217 -0.166421  0.327770
# ZN      -0.180980  1.000000 -0.516206 -0.054499 -0.499150  0.317100 -0.561786
# INDUS    0.377368 -0.516206  1.000000  0.041804  0.767807 -0.397387  0.620594
# CHAS    -0.050280 -0.054499  0.041804  1.000000  0.103935  0.043610  0.084866
# NOX      0.392217 -0.499150  0.767807  0.103935  1.000000 -0.336953  0.714644
# RM      -0.166421  0.317100 -0.397387  0.043610 -0.336953  1.000000 -0.249920
# AGE      0.327770 -0.561786  0.620594  0.084866  0.714644 -0.249920  1.000000
# DIS     -0.354935  0.677879 -0.720415 -0.090020 -0.769398  0.259068 -0.738806
# RAD      0.614471 -0.297670  0.573426 -0.027484  0.582393 -0.156789  0.428523
# TAX      0.553746 -0.287649  0.698413 -0.059928  0.651532 -0.258840  0.473898
# PTRATIO  0.258989 -0.383582  0.375134 -0.124379  0.181745 -0.236521  0.289379
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dat.corr(),annot=True)
# Out:
# <Axes: >

# %%
#lstat,tax,indus,dis

# %%
dat.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
dat[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
         'PTRATIO', 'B', 'LSTAT', 'MEDV']]=mm.fit_transform(dat[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT', 'MEDV']])

# %%
dat
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.058148   0.0  0.314815  0.577505  0.641607  0.265966
# 1    0.000236  0.00  0.234444   0.0  0.172840  0.547998  0.782698  0.346078
# 2    0.000236  0.00  0.234444   0.0  0.172840  0.694386  0.599382  0.346078
# 3    0.000293  0.00  0.053333   0.0  0.150206  0.658555  0.441813  0.446102
# 4    0.000705  0.00  0.053333   0.0  0.150206  0.687105  0.528321  0.446102
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 600  0.000380  0.80  0.028889   0.0  0.039095  0.713930  0.321318  0.559981
# 601  0.001713  0.00  0.372963   0.0  0.057613  0.459858  0.150360  0.375324
# 602  0.002046  0.00  0.228519   0.0  0.129630  0.426327  0.313079  0.358253
# 604  0.000533  0.00  0.488148   0.0  0.106996  0.572523  0.495366  0.436804
# 605  0.000430  0.25  0.152593   0.0  0.084362  0.585936  0.695160  0.385682
#
# ...

# %%
x=dat[['CRIM', 'ZN', 'CHAS', 'NOX', 'RM',
       'PTRATIO', 'B']]
#lstat,tax,indus,dis
x.shape
# Out:
# (557, 7)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(x.corr(),annot=True)
# Out:
# <Axes: >

# %%
y=dat['MEDV']
y.shape
# Out:
# (557,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=45)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_predict=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
r2=r2_score(y_test,y_predict)
r2
# Out:
# 0.5648369333054908

# %%
X=dat[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
         'PTRATIO', 'B', 'LSTAT']]
Y=dat['MEDV']

# %%
X
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.058148   0.0  0.314815  0.577505  0.641607  0.265966
# 1    0.000236  0.00  0.234444   0.0  0.172840  0.547998  0.782698  0.346078
# 2    0.000236  0.00  0.234444   0.0  0.172840  0.694386  0.599382  0.346078
# 3    0.000293  0.00  0.053333   0.0  0.150206  0.658555  0.441813  0.446102
# 4    0.000705  0.00  0.053333   0.0  0.150206  0.687105  0.528321  0.446102
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 600  0.000380  0.80  0.028889   0.0  0.039095  0.713930  0.321318  0.559981
# 601  0.001713  0.00  0.372963   0.0  0.057613  0.459858  0.150360  0.375324
# 602  0.002046  0.00  0.228519   0.0  0.129630  0.426327  0.313079  0.358253
# 604  0.000533  0.00  0.488148   0.0  0.106996  0.572523  0.495366  0.436804
# 605  0.000430  0.25  0.152593   0.0  0.084362  0.585936  0.695160  0.385682
#
#           RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2, random_state=45)

# %%
X_test.shape
# Out:
# (112, 13)

# %%
Y_test.shape
# Out:
# (112,)

# %%
from xgboost import XGBRegressor as xGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
xgb = xGBRegressor() 
xgb.fit(X_train,Y_train)
xgbtd=xgb.predict(X_test)
xgbr2=r2_score(Y_test,xgbtd)

# %%
xgbr2
# Out:
# 0.9124245866214299
