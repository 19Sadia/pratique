# %% [markdown]
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
n=np.array([1,2,3,5])
h=np.array([3,5,6,7])
plt.plot(n,h)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
g=pd.Series([1,2,3,5,6])
h=pd.Series([9,8,7,6,5])
plt.plot(g,h)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Plotting x and y points
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %%
arr=np.array([1,3])
arr1=np.array([3,10])
plt.plot(arr,arr1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
arr=np.array([1,3]) # without line
arr1=np.array([3,10])
plt.plot(arr,arr1,'*')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Multiple Points
# You can plot as many points as you like, just make sure you have the same number of points in both axis.

# %%
arr=np.array([1,2,3,6]) # without line
arr1=np.array([3,8,1,9])
plt.plot(arr,arr1,)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Default X-Points
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
arr=np.array([2,4,6,4,6,10])
plt.plot(arr)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Markers
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
arr=np.array([2,4,6,4,6,10])
plt.plot(arr, marker='o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
arr=np.array([1,2,3,6]) # without line
arr1=np.array([3,8,1,9])
plt.plot(arr,arr1, marker='s')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [raw]
# Marker Reference
# You can choose any of these markers:
#
# Marker	Description
# 'o'	Circle
# '*'	Star
# '.'	Point
# ','	Pixel
# 'x'	X
# 'X'	X (filled)
# '+'	Plus
# 'P'	Plus (filled)
# 's'	Square
# 'D'	Diamond
# 'd'	Diamond (thin)
# 'p'	Pentagon
# 'H'	Hexagon
# 'h'	Hexagon
# 'v'	Triangle Down
# '^'	Triangle Up
# '<'	Triangle Left
# '>'	Triangle Right
# '1'	Tri Down
# '2'	Tri Up
# '3'	Tri Left
# '4'	Tri Right
# '|'	Vline
# '_'	Hline

# %% [markdown]
# ## Format Strings fmt
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %% [raw]
# Line Syntax	Description
# '-'	Solid line
# ':'	Dotted line
# '--'	Dashed line
# '-.'	Dashed/dotted line

# %%
arr=np.array([1,2,3,6]) # without line
arr1=np.array([3,8,1,9])
plt.plot(arr,arr1, 'd:c')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [raw]
# 'r'	Red
# 'g'	Green
# 'b'	Blue
# 'c'	Cyan
# 'm'	Magenta
# 'y'	Yellow
# 'k'	Black
# 'w'	White

# %% [markdown]
# ### Marker Size
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers:

# %%
arr=np.array([2,4,6,4,6,10])
plt.plot(arr, 'o:m', ms=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Marker Color
# You can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers:

# %%
arr=np.array([2,4,6,4,6,10])
plt.plot(arr, 'o:b', ms=20, mec='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### You can use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

# %%
arr=np.array([2,4,6,4,6,10])
plt.plot(arr, 'o:b', ms=20, mfc='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Using both mec and mfc

# %%
arr=np.array([2,4,6,4,6,10])
plt.plot(arr, 'o:b', ms=12,mec='r', mfc='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
arr=np.array([2,4,6,4,6,10])
plt.plot(arr, 'o:b', ms=12,mec='hotpink', mfc='hotpink')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Matplotlib Labels and Title

# %% [markdown]
# Create Labels for a Plot
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.

# %%
import numpy as np

# %%
n=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(n,m)

plt.xlabel="Average Pulse"
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# #### Create a Title for a Plot

# %%
n=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(n,m)

plt.title('Sport watch data')
plt.xlabel("Average Pulse")
plt.ylabel('calories burnage')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Set Font Properties for Title and Labels
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
n=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(n,m)

plt.title('sport watch data', fontdict = font1)
plt.xlabel("average", fontdict=font2)
plt.ylabel('calaories', fontdict=font2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
#       4 plt.plot(n,m)
# ----> 6 plt.title('sport watch data', fontdict = font1)
#       7 plt.xlabel("average", fontdict=font2)
#       8 plt.ylabel('calaories', fontdict=font2)
#
# NameError: name 'font1' is not defined

# %% [markdown]
# #### Position the Title
# You can use the loc parameter in title() to position the title.
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
n=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(n,m)

plt.title("sport watch data", loc='left')
plt.xlabel("average", fontdict=font2)
plt.ylabel("calories", fontdict=font2)
plt.show()

# %% [markdown]
# ## Matplotlib Adding Grid Lines
# Add Grid Lines to a Plot
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
n=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])


plt.title("sport watch data", loc='left')
plt.xlabel("average", fontdict=font2)
plt.ylabel("calories", fontdict=font2)
plt.plot(n,m)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
#       5 plt.title("sport watch data", loc='left')
# ----> 6 plt.xlabel("average", fontdict=font2)
#       7 plt.ylabel("calories", fontdict=font2)
#       8 plt.plot(n,m)
#
# NameError: name 'font2' is not defined

# %%
n=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("sport watch data")
plt.xlabel("average")
plt.ylabel("calories")

plt.plot(n,m)
plt.grid(axis='x')
plt.show()

# %%
n=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("sport watch data")
plt.xlabel("average")
plt.ylabel("calories")

plt.plot(n,m)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### Set Line Properties for the Grid
# You can also set the line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number).

# %%
n=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
m=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("sport watch data")
plt.xlabel("average")
plt.ylabel("calories")

plt.plot(n,m)
plt.grid(color = 'green', linestyle = ':', linewidth = 0.5)
plt.show()

# %% [markdown]
# ## Matplotlib Subplot
# Display Multiple Plots
# With the subplot() function you can draw multiple plots in one figure:

# %%
import numpy as np
# plot 1

a=np.array([1,2,3,4])
b=np.array([3, 8, 1, 10])

plt.subplot(2,1,2)
plt.plot(a,b)

# plot 2

c=np.array([1,2,3,4])
d=np.array([10, 20, 30, 40])

plt.subplot(2,2,2)
plt.plot(c,d)

# %%
# plot 1

a=np.array([1,2,3,4])
b=np.array([3, 8, 1, 10])

plt.subplot(2,2,2)
plt.plot(a,b)

# plot 2

c=np.array([1,2,3,4])
d=np.array([10, 20, 30, 40])

plt.subplot(2,2,2)
plt.plot(c,d)

# %%
# plot 1

a=np.array([1,2,3,4])
b=np.array([3, 8, 1, 10])

plt.subplot(2,1,1)
plt.plot(a,b)

# plot 2

c=np.array([1,2,3,4])
d=np.array([10, 20, 30, 40])

plt.subplot(2,1,2)
plt.plot(c,d)

# %%
# 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,3,1)
plt.plot(x,y)

#2 
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2,3,2)
plt.plot(x,y)

# 3
x = np.array([1,2,3,4])
y = np.array([3,10,8,1])

plt.subplot(2,3,3)
plt.plot(x,y)

# 4
x = np.array([2,4,3,6,5])
y = np.array([10,40,20,44,22])

plt.subplot(2,3,4)
plt.plot(x,y)

# 5 
x = np.array([6,8,4,9])
y = np.array([10,30,20,40])

plt.subplot(2,3,5)
plt.plot(x,y)

# 6
x = np.array([0, 1, 2, 3])
y = np.array([4,6,9,2])

plt.subplot(2,3,6)
plt.plot(x,y)

# %% [markdown]
# ### Title
# You can add a title to each plot with the title() function:

# %%
# 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,3,1)
plt.plot(x,y)
plt.title('sale')

#2 
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2,3,2)
plt.plot(x,y)
plt.title('average')

# 3
x = np.array([1,2,3,4])
y = np.array([3,10,8,1])

plt.subplot(2,3,3)
plt.plot(x,y)
plt.title('profit')

# 4
x = np.array([2,4,3,6,5])
y = np.array([10,40,20,44,22])

plt.subplot(2,3,4)
plt.plot(x,y)
plt.title('lose')

# 5 
x = np.array([6,8,4,9])
y = np.array([10,30,20,40])

plt.subplot(2,3,5)
plt.plot(x,y)
plt.title('data')

# 6
x = np.array([0, 1, 2, 3])
y = np.array([4,6,9,2])

plt.subplot(2,3,6)
plt.plot(x,y)
plt.title('game')
# Out:
# Text(0.5, 1.0, 'game')

# %% [markdown]
# #### Super Title
# You can add a title to the entire figure with the suptitle() function:

# %%
# 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,3,1)
plt.plot(x,y)
plt.title('sale')

#2 
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2,3,2)
plt.plot(x,y)
plt.title('average')

# 3
x = np.array([1,2,3,4])
y = np.array([3,10,8,1])

plt.subplot(2,3,3)
plt.plot(x,y)
plt.title('profit')

# 4
x = np.array([2,4,3,6,5])
y = np.array([10,40,20,44,22])

plt.subplot(2,3,4)
plt.plot(x,y)
plt.title('lose')

# 5 
x = np.array([6,8,4,9])
y = np.array([10,30,20,40])

plt.subplot(2,3,5)
plt.plot(x,y)
plt.title('watch')

# 6
x = np.array([0, 1, 2, 3])
y = np.array([4,6,9,2])

plt.subplot(2,3,6)
plt.plot(x,y)
plt.title('game')

plt.suptitle("data")
plt.show()

# %% [markdown]
# ## Matplotlib Scatter
# Creating Scatter Plots
# With Pyplot, you can use the scatter() function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
n=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
m=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# #### Compare Plots
# In the example above, there seems to be a relationship between speed and age, but what if we plot the observations from another day as well? Will the scatter plot tell us something else?

# %%
# 1
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
#2 
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# #### Colors
# You can set your own color for each scatter plot with the color or the c argument:

# %%
# 1
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, c='red')
#2 
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, c='green')

plt.show()

# %% [markdown]
# ### Color Each Dot
# You can even set a specific color for each dot by using an array of colors as value for the c argument:
#
# Note: You cannot use the color argument for this, only the c argument.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
c=np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x,y,color=c)
plt.show()

# %% [markdown]
# ### ColorMap
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# Here is an example of a colormap:
#
#
#
# This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, up to 100, which is a yellow color.
#
# How to Use the ColorMap
# You can specify the colormap with the keyword argument cmap with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
#
# In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %% [markdown]
# ### You can include the colormap in the drawing by including the plt.colorbar() statement:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()

plt.show()

# %%
Accent		 	Accent_r	
Blues		 	Blues_r	
BrBG		 	BrBG_r	
BuGn		 	BuGn_r	
BuPu		 	BuPu_r	
CMRmap		 	CMRmap_r	
Dark2		 	Dark2_r	
GnBu		 	GnBu_r	
Greens		 	Greens_r	
Greys		 	Greys_r	
OrRd		 	OrRd_r	
Oranges		 	Oranges_r	
PRGn		 	PRGn_r	
Paired		 	Paired_r	
Pastel1		 	Pastel1_r	
Pastel2		 	Pastel2_r	
PiYG		 	PiYG_r	
PuBu		 	PuBu_r	
PuBuGn		 	PuBuGn_r	
PuOr		 	PuOr_r	
PuRd		 	PuRd_r	
Purples		 	Purples_r	
RdBu		 	RdBu_r	
RdGy		 	RdGy_r	
RdPu		 	RdPu_r	
RdYlBu		 	RdYlBu_r	
RdYlGn		 	RdYlGn_r	
Reds		 	Reds_r	
Set1		 	Set1_r	
Set2		 	Set2_r	
Set3		 	Set3_r	
Spectral		 	Spectral_r	
Wistia		 	Wistia_r	
YlGn		 	YlGn_r	
YlGnBu		 	YlGnBu_r	
YlOrBr		 	YlOrBr_r	
YlOrRd		 	YlOrRd_r	
afmhot		 	afmhot_r	
autumn		 	autumn_r	
binary		 	binary_r	
bone		 	bone_r	
brg		 	brg_r	
bwr		 	bwr_r	
cividis		 	cividis_r	
cool		 	cool_r	
coolwarm		 	coolwarm_r	
copper		 	copper_r	
cubehelix		 	cubehelix_r	
flag		 	flag_r	
gist_earth		 	gist_earth_r	
gist_gray		 	gist_gray_r	
gist_heat		 	gist_heat_r	
gist_ncar		 	gist_ncar_r	
gist_rainbow		 	gist_rainbow_r	
gist_stern		 	gist_stern_r	
gist_yarg		 	gist_yarg_r	
gnuplot		 	gnuplot_r	
gnuplot2		 	gnuplot2_r	
gray		 	gray_r	
hot		 	hot_r	
hsv		 	hsv_r	
inferno		 	inferno_r	
jet		 	jet_r	
magma		 	magma_r	
nipy_spectral		 	nipy_spectral_r	
ocean		 	ocean_r	
pink		 	pink_r	
plasma		 	plasma_r	
prism		 	prism_r	
rainbow		 	rainbow_r	
seismic		 	seismic_r	
spring		 	spring_r	
summer		 	summer_r	
tab10		 	tab10_r	
tab20		 	tab20_r	
tab20b		 	tab20b_r	
tab20c		 	tab20c_r	
terrain		 	terrain_r	
twilight		 	twilight_r	
twilight_shifted		 	twilight_shifted_r	
viridis		 	viridis_r	
winter		 	winter_r	
Size

# %%
x=np.random.randint(100, size=100)
y=np.random.randint(100, size=100)
color=np.random.randint(100, size=100)

plt.scatter(x,y, c=color, cmap='Accent')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.random.randint(100, size=100)
y=np.random.randint(100, size=100)
color=np.random.randint(100, size=100)

plt.scatter(x,y, c=color, cmap='Blues')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.random.randint(100, size=100)
y=np.random.randint(100, size=100)
color=np.random.randint(100, size=100)

plt.scatter(x,y, c=color, cmap='copper')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.random.randint(100, size=100)
y=np.random.randint(100, size=100)
color=np.random.randint(100, size=100)

plt.scatter(x,y, c=color, cmap='twilight')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Size
# You can change the size of the dots with the s argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %%
x=np.random.randint(100, size=100)
y=np.random.randint(100, size=100)
color=np.random.randint(100, size=100)
sizes=np.random.randint(100, size=100)
plt.scatter(x,y, s=sizes)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Alpha
# You can adjust the transparency of the dots with the alpha argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %%
x=np.random.randint(100, size=100)
y=np.random.randint(100, size=100)
color=np.random.randint(100, size=100)
sizes=np.random.randint(100, size=100)
plt.scatter(x,y, alpha=0.5, s=sizes)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Combine Color Size and Alpha
# You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent:

# %%
x=np.random.randint(100, size=100)
y=np.random.randint(100, size=100)
color=np.random.randint(100, size=100)
sizes=10*np.random.randint(100, size=100)
plt.scatter(x,y, c=color, alpha=0.5, s=sizes , cmap='spring')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Matplotlib Bars
# Creating Bars
# With Pyplot, you can use the bar() function to draw bar graphs:

# %%
n=np.array([1,2,3,4])
m=np.array(['A','B','C','D'])
plt.bar(n,m)
plt.show()

# %% [markdown]
# ## Horizontal Bars
# If you want the bars to be displayed horizontally instead of vertically, use the barh() function:

# %%
a=np.array(['A','B','C','D'])
b=np.array([1,2,3,4])

plt.barh(a,b)
plt.show()

# %% [markdown]
# ### Bar Color
# The bar() and barh() take the keyword argument color to set the color of the bars:

# %%
n=np.array([1,2,3,4])
m=np.array(['A','B','C','D'])
plt.bar(n,m, color='red')
plt.show()

# %%
a=np.array(['A','B','C','D'])
b=np.array([1,2,3,4])

plt.barh(a,b, color='green')
plt.show()

# %% [markdown]
# ### Bar Width
# The bar() takes the keyword argument width to set the width of the bars:

# %%
n=np.array([1,2,3,4])
m=np.array(['A','B','C','D'])
plt.bar(n,m, color='red', width=0.1)
plt.show()

# %% [markdown]
# ### Bar Height
# The barh() takes the keyword argument height to set the height of the bars:

# %%
a=np.array(['A','B','C','D'])
b=np.array([1,2,3,4])

plt.barh(a,b, color='green', height=0.5)
plt.show()

# %% [markdown]
# ## Matplotlib Histograms
# Create Histogram
# In Matplotlib, we use the hist() function to create histograms.
#
# The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument.
#
# For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10. Learn more about Normal Data Distribution in our Machine Learning Tutorial.

# %%
b=np.random.normal(170,10,250)
b
plt.hist(b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Matplotlib Pie Charts
# Creating Pie Charts
# With Pyplot, you can use the pie() function to draw pie charts:

# %%
f=np.array([50,50])
plt.pie(f)
plt.show()

# %%
f=np.array([10,30,50,70,90])
plt.pie(f)
plt.show()

# %% [markdown]
# ### Labels
# Add labels to the pie chart with the label parameter.
#
# The label parameter must be an array with one label for each wedge:

# %%
f=np.array([10,30,50,70,90])
m=['A','B','C','D','E']
plt.pie(f, labels=m)
plt.show()

# %% [markdown]
# ### Start Angle
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %%
f=np.array([10,30,50,70,90])
m=['A','B','C','D','E']
plt.pie(f, labels=m, startangle=90)
plt.show()

# %% [markdown]
# ### Explode
# Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
f=np.array([10,30,50,70,90])
m=['A','B','C','D','E']
e=[0,0,0,0,0.2]
plt.pie(f, labels=m, startangle=90, explode=e)
plt.show()

# %% [markdown]
# ### Shadow
# Add a shadow to the pie chart by setting the shadows parameter to True:

# %%
f=np.array([10,30,50,70,90])
m=['A','B','C','D','E']
e=[0,0,0,0,0.2]
plt.pie(f, labels=m, startangle=90, explode=e, shadow=True)
plt.show()

# %% [markdown]
# ### Colors
# You can set the color of each wedge with the colors parameter.
#
# The colors parameter, if specified, must be an array with one value for each wedge:

# %% [raw]
# You can use Hexadecimal color values, any of the 140 supported color names, or one of these shortcuts:
#
# 'r' - Red
# 'g' - Green
# 'b' - Blue
# 'c' - Cyan
# 'm' - Magenta
# 'y' - Yellow
# 'k' - Black
# 'w' - White

# %%
f=np.array([10,30,50,70,90])
m=['A','B','C','D','E']
e=[0,0,0,0,0.2]
mycolor=['r','g','b','m','k']
plt.pie(f, labels=m, startangle=90, explode=e, shadow=True, colors=mycolor)
plt.show()

# %% [markdown]
# ### Legend
# To add a list of explanation for each wedge, use the legend() function:

# %%
f=np.array([10,30,50,70,90])
m=['A','B','C','D','E']
e=[0,0,0,0,0.2]
mycolor=['r','g','b','m','k']
plt.pie(f, labels=m, startangle=90, explode=e, shadow=True, colors=mycolor)
plt.legend()
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ### Legend With Header
# To add a header to the legend, add the title parameter to the legend function.

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title='Fruits')
plt.show()
